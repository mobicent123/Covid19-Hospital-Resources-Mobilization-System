# %%
__author__ = "Abdul Rahman"
__copyright__ = "Copyright 2021, Datastax Astra Hackathon"
__credits__ = []
__license__ = "GPL"
__version__ = "0.1"
__maintainer__ = "Abdul Rahman"
__email__ = "arahman1214.ar@gmail.com"
__status__ = "Hackathon"

from cassandra.cluster import Cluster
from cassandra.auth import PlainTextAuthProvider
from cassandra import ConsistencyLevel
from cassandra.query import SimpleStatement
from csv import reader
import random
import decimal

# Importing the os library
import os


auth_provider = PlainTextAuthProvider('wjmCJxDaEAUuMRFXhMARIbux', \
                                      'zhn4+.m,ahYKNlvZhf1CC6EzFyOnwrA.uoDLsMyW2.MF1siTs1kKcfv3KwZUrMcEZmjHgf.-LYGWl5Yq-moBCd6kbr6aqDslJx8bxGfKaZecv44iOcQWM+TncI6phFLI')


# BLOCK A - INVENTORY FETCH FROM DATASTAX
cloud_config= {
        'secure_connect_bundle': 'secure-connect-inventory.zip'
}
cluster = Cluster(cloud=cloud_config, auth_provider=auth_provider)
session = cluster.connect()
session.set_keyspace('Inventory')

astraRows = session.execute('SELECT COUNT(1) FROM Inventory')

for astraRow in astraRows:
    print(astraRow)


# Open a file: file
dashboardFile = open('Dashboard.html',mode='r')
# read all lines at once
dashboardFileText = dashboardFile.read()
dashboardFileText = dashboardFileText.replace("##TOTALINVENTORY##",str(astraRow[0]))
# close the file
dashboardFile.close()

dashboardFileUpdate = open("Dashboard.html","w")
# \n is placed to indicate EOL (End of Line)
dashboardFileUpdate.write(dashboardFileText);
dashboardFileUpdate.close()
print("Inventory values updated successfully !")


# BLOCK B - ASSETS FETCH FROM DATASTAX
cloud_config= {
        'secure_connect_bundle': 'secure-connect-assets.zip'
}
cluster = Cluster(cloud=cloud_config, auth_provider=auth_provider)
session = cluster.connect()
session.set_keyspace('Asset')

astraRows = session.execute('SELECT COUNT(1) FROM Asset')

for astraRow in astraRows:
    print(astraRow)


# Open a file: file
dashboardFile = open('Dashboard.html',mode='r')
# read all lines at once
dashboardFileText = dashboardFile.read()
dashboardFileText = dashboardFileText.replace("##TOTALASSETS##",str(astraRow[0]))
# close the file
dashboardFile.close()

dashboardFileUpdate = open("Dashboard.html","w")
# \n is placed to indicate EOL (End of Line)
dashboardFileUpdate.write(dashboardFileText);
dashboardFileUpdate.close()
print("Assets values updated successfully !")



# BLOCK C - TRANSPORT FETCH FROM DATASTAX
cloud_config= {
        'secure_connect_bundle': 'secure-connect-transport.zip'
}
cluster = Cluster(cloud=cloud_config, auth_provider=auth_provider)
session = cluster.connect()
session.set_keyspace('Transport')

astraRows = session.execute('SELECT COUNT(1) FROM Transport')

for astraRow in astraRows:
    print(astraRow)


# Open a file: file
dashboardFile = open('Dashboard.html',mode='r')
# read all lines at once
dashboardFileText = dashboardFile.read()
dashboardFileText = dashboardFileText.replace("##TOTALTRANSPORT##",str(astraRow[0]))
# close the file
dashboardFile.close()

dashboardFileUpdate = open("Dashboard.html","w")
# \n is placed to indicate EOL (End of Line)
dashboardFileUpdate.write(dashboardFileText);
dashboardFileUpdate.close()
print("Transport values updated successfully !")
    
# BLOCK D - PATIENTS FETCH FROM DATASTAX
cloud_config= {
        'secure_connect_bundle': 'secure-connect-patients.zip'
}
cluster = Cluster(cloud=cloud_config, auth_provider=auth_provider)
session = cluster.connect()
session.set_keyspace('Patient')

astraRows = session.execute('SELECT COUNT(1) FROM Patient')

for astraRow in astraRows:
    print(astraRow)


# Open a file: file
dashboardFile = open('Dashboard.html',mode='r')
# read all lines at once
dashboardFileText = dashboardFile.read()
dashboardFileText = dashboardFileText.replace("##TOTALPATIENTS##",str(astraRow[0]))
# close the file
dashboardFile.close()

dashboardFileUpdate = open("Dashboard.html","w")
# \n is placed to indicate EOL (End of Line)
dashboardFileUpdate.write(dashboardFileText);
dashboardFileUpdate.close()
print("Patients values updated successfully !")

# BLOCK E - CASES FETCH FROM DATASTAX
cloud_config= {
        'secure_connect_bundle': 'secure-connect-cases.zip'
}
cluster = Cluster(cloud=cloud_config, auth_provider=auth_provider)
session = cluster.connect()
session.set_keyspace('Case')

astraRows = session.execute('SELECT COUNT(1) FROM Case')

for astraRow in astraRows:
    print(astraRow)


# Open a file: file
dashboardFile = open('Dashboard.html',mode='r')
# read all lines at once
dashboardFileText = dashboardFile.read()
dashboardFileText = dashboardFileText.replace("##TOTALCASES##",str(astraRow[0]))
# close the file
dashboardFile.close()

dashboardFileUpdate = open("Dashboard.html","w")
# \n is placed to indicate EOL (End of Line)
dashboardFileUpdate.write(dashboardFileText);
dashboardFileUpdate.close()
print("CASES values updated successfully !")
# Out:
# Row(count=13631)
# Inventory values updated successfully !
# Row(count=15848)
# Assets values updated successfully !
# Row(count=38)
# Transport values updated successfully !
# Row(count=18437)
# Patients values updated successfully !
# Row(count=8024)
# CASES values updated successfully !
